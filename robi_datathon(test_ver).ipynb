# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import array as arr
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
ds = pd.read_csv('train.csv')

# %%
ds
# Out:
#                                                       id gender s11 s12  s13  \
# 0      b'gAAAAABinOicS09vrmgh0_JyEHihI13ptO0rCyHP7l76...      M   Y   N    1
# 1      b'gAAAAABinOiWGC1WhR6WYP0DA5ssGv9rIekrWUwCdJ8F...      M   Y   Y    1
# 2      b'gAAAAABinOibTcOBFIVeA4nVF3FuFz_QX3ZlPPFc21gS...      M   Y   Y    1
# 3      b'gAAAAABinOig-g3-Q1ggjlMhfUSdn21Aj5yVVeVvXbis...      F   Y   Y    1
# 4      b'gAAAAABinOiXdoaNUzihOSbyY1tjWtd5EgMaXkkvH6SV...      M   N   Y    1
# ...                                                  ...    ...  ..  ..  ...
# 28317  b'gAAAAABinOiX2ss5U2ZT5zFd8zf7HcBDWPvbivNz5wAy...      M   Y   Y    1
# 28318  b'gAAAAABinOiabmEADrCTZQktCKiahJkR_0kDa_8WOlos...      M   Y   Y    1
# 28319  b'gAAAAABinOicscC37w1W9uiIlYL1U5D_mUtmgdUg8QTl...      F   Y   Y    1
# 28320  b'gAAAAABinOib-JZ8iQDxjSRsa1dPT1TqeSQ_si4mAw5f...      M   Y   Y    1
# 28321  b'gAAAAABinOiZ3mCQAtoJFXj-Ymjhi9FbbZ_Ypi5gDoAE...      M   Y   Y    1
#
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28322 entries, 0 to 28321
# Data columns (total 36 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      28322 non-null  object
#  1   gender  28322 non-null  object
#  2   s11     28322 non-null  object
#  3   s12     28322 non-null  object
#  4   s13     28322 non-null  int64
#  5   s16     28322 non-null  object
#  6   s17     28322 non-null  object
#  7   s18     28322 non-null  object
#  8   s48     28322 non-null  int64
#  9   s52     28322 non-null  object
#  10  s53     28322 non-null  object
#  11  s54     2628 non-null   object
#  12  s55     3206 non-null   object
#  13  s56     0 non-null      float64
#  14  s57     0 non-null      float64
#  15  s58     28322 non-null  object
#  16  s59     0 non-null      float64
#  17  s69     28322 non-null  object
#  18  s70     28322 non-null  object
#  19  s71     28322 non-null  object
#  20  n1      28322 non-null  float64
# ...

# %%
ds.describe()
# Out:
#                 s13           s48  s56  s57  s59            n1            n2  \
# count  28322.000000  28322.000000  0.0  0.0  0.0  28322.000000  28322.000000
# mean       0.983123      0.433338  NaN  NaN  NaN     10.201863      1.600111
# std        0.128814      0.495545  NaN  NaN  NaN      4.414660      0.664985
# min        0.000000      0.000000  NaN  NaN  NaN      2.200736      0.311727
# 25%        1.000000      0.000000  NaN  NaN  NaN      6.592127      1.013540
# 50%        1.000000      0.000000  NaN  NaN  NaN      9.535961      1.462197
# 75%        1.000000      1.000000  NaN  NaN  NaN     14.432580      2.194510
# max        1.000000      1.000000  NaN  NaN  NaN     20.882733      3.137331
#
#                  n3            n4            n5  ...            n7  \
# count  28322.000000  28322.000000  28322.000000  ...  28322.000000
# mean       4.805099      5.080537    -32.641183  ...     -9.107429
# std        2.199282      2.276162      0.241453  ...      0.205200
# ...

# %%
numeric_cols = ds.select_dtypes(include=['int64', 'float64']).columns.tolist()

# %%
print(list(numeric_cols))
# Out:
# ['s13', 's48', 's56', 's57', 's59', 'n1', 'n2', 'n3', 'n4', 'n5', 'n6', 'n7', 'n8', 'n9', 'n10', 'n11', 'n12', 'n13', 'n14', 'n15', 'label']

# %%
categorical_cols = ds.select_dtypes(include='object').columns.tolist()

# %%
print(list(categorical_cols))
# Out:
# ['id', 'gender', 's11', 's12', 's16', 's17', 's18', 's52', 's53', 's54', 's55', 's58', 's69', 's70', 's71']

# %%
missing_counts = ds[numeric_cols].isna().sum().sort_values(ascending=False)
missing_counts[missing_counts > 0]
# Out:
# s56    28322
# s57    28322
# s59    28322
# dtype: int64

# %%
ds.values
# Out:
# array([["b'gAAAAABinOicS09vrmgh0_JyEHihI13ptO0rCyHP7l76be71PWA2ReUc4HUQn16Fya1z8_VStNnFGaXJF262CgsuMPzOaknSeg=='",
#         'M', 'Y', ..., 0.631220343, 5, 0],
#        ["b'gAAAAABinOiWGC1WhR6WYP0DA5ssGv9rIekrWUwCdJ8FvkVcSUl2AquMfWqtOqs3AQYGxS13wQv9Tx4GEkPEl5RnbchazqsZcw=='",
#         'M', 'Y', ..., 0.392746019, 3, 1],
#        ["b'gAAAAABinOibTcOBFIVeA4nVF3FuFz_QX3ZlPPFc21gS9EYdw6Wo8Y5agbzfD6hhsaXZCBdrUQVPpZBXYsODc2PDjER2DX5QcA=='",
#         'M', 'Y', ..., 0.222536676, 2, 0],
#        ...,
#        ["b'gAAAAABinOicscC37w1W9uiIlYL1U5D_mUtmgdUg8QTlgTDiCQj0N8l5xVuD5tTmGrYgogJLq-v9Z6fCyGeAng__ulkRJQi-Xg=='",
#         'F', 'Y', ..., 0.826586671, 1, 0],
#        ["b'gAAAAABinOib-JZ8iQDxjSRsa1dPT1TqeSQ_si4mAw5fX_kDmvIAkIofJCd_35viYIE5AhMTE-MYsS5yYkiD_9J6ewDjL1cYuQ=='",
#         'M', 'Y', ..., 0.103523331, 5, 0],
#        ["b'gAAAAABinOiZ3mCQAtoJFXj-Ymjhi9FbbZ_Ypi5gDoAEYe1Cx66GhkhZ5UIJNLcPlgrRyfpabvIwD5ok1GxipWfkujjwXyMMBw=='",
# ...

# %%
ds=ds.drop(columns=['s56','s57','s59'], axis=1)

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28322 entries, 0 to 28321
# Data columns (total 33 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      28322 non-null  object
#  1   gender  28322 non-null  object
#  2   s11     28322 non-null  object
#  3   s12     28322 non-null  object
#  4   s13     28322 non-null  int64
#  5   s16     28322 non-null  object
#  6   s17     28322 non-null  object
#  7   s18     28322 non-null  object
#  8   s48     28322 non-null  int64
#  9   s52     28322 non-null  object
#  10  s53     28322 non-null  object
#  11  s54     2628 non-null   object
#  12  s55     3206 non-null   object
#  13  s58     28322 non-null  object
#  14  s69     28322 non-null  object
#  15  s70     28322 non-null  object
#  16  s71     28322 non-null  object
#  17  n1      28322 non-null  float64
#  18  n2      28322 non-null  float64
#  19  n3      28322 non-null  int64
#  20  n4      28322 non-null  float64
# ...

# %%
plt.figure(figsize =(5, 5))
plt.bar(ds['n1'],ds['label'], width = 0.01, color ='red')
plt.show()

# %%
plt.figure(figsize =(5, 5))
plt.scatter(ds['n2'],ds['label'], label= "stars", color= "green", marker= "*", s=1)

plt.show()

# %%
test=pd.read_csv('test.csv')
test
# Out:
#                                                       id gender s11 s12  s13  \
# 0      b'gAAAAABinOi328DZcweGB4_nOyHA3Dy6o1YKYKyf3COx...      M   Y   Y    1
# 1      b'gAAAAABinOikutEIBjkUXl9lYTg4RI6jc4NfiMUCcVsn...      M   Y   Y    1
# 2      b'gAAAAABinOjBM70jBXOroAlUSq5lNXMd_oP0PU7jLQE5...      M   Y   N    1
# 3      b'gAAAAABinOimitAnqlgOcqnD_LeNL3WEbXNGvjd3QVPi...      M   Y   Y    1
# 4      b'gAAAAABinOi3W9p3Oka5MV_dc2TeorZUcIWOnnODSx7E...      M   Y   Y    1
# ...                                                  ...    ...  ..  ..  ...
# 85060  b'gAAAAABinOjbnJVk2-nOVQsYB9p4DK26fTLLik_UR2H0...      M   Y   Y    1
# 85061  b'gAAAAABinOi7ixyXrlKYlx8D9i0-TIPD5elP2k-vuekn...      M   Y   Y    1
# 85062  b'gAAAAABinOi31zWSlD0OMhbBd3_weh7Kq6aPeO4yYqns...      M   N   Y    1
# 85063  b'gAAAAABinOjIe7jFVk9k7jiH8Y3rdpUHDTZG2T2isunp...      M   N   Y    1
# 85064  b'gAAAAABinOiiLo4KNZVgClHgtOFRzEU9O97My6MowJFa...      M   Y   Y    1
#
# ...

# %%
train_len=len(ds)
df=pd.concat([ds,test], axis=0)
df=df.reset_index(drop=True)

# %%
df.head()
# Out:
#                                                   id gender s11 s12  s13 s16  \
# 0  b'gAAAAABinOicS09vrmgh0_JyEHihI13ptO0rCyHP7l76...      M   Y   N    1   D
# 1  b'gAAAAABinOiWGC1WhR6WYP0DA5ssGv9rIekrWUwCdJ8F...      M   Y   Y    1   D
# 2  b'gAAAAABinOibTcOBFIVeA4nVF3FuFz_QX3ZlPPFc21gS...      M   Y   Y    1   D
# 3  b'gAAAAABinOig-g3-Q1ggjlMhfUSdn21Aj5yVVeVvXbis...      F   Y   Y    1   D
# 4  b'gAAAAABinOiXdoaNUzihOSbyY1tjWtd5EgMaXkkvH6SV...      M   N   Y    1   B
#
#   s17 s18  s48 s52  ...       n10       n11 n12 n13       n14 n15 label  s56  \
# 0   D   B    0   1  ...  4.804517  1.544484   0   0  0.631220   5   0.0  NaN
# 1   D   B    1   1  ...  6.110416  1.712354   0   0  0.392746   3   1.0  NaN
# 2   D   B    0   1  ...  3.953226  1.804260   0   0  0.222537   2   0.0  NaN
# 3   D   B    0   1  ...  4.559419  1.537645   0   0  0.154409   4   0.0  NaN
# 4   D   D    1   l  ...  4.052003  1.637831   0   1  0.737560   1   0.0  NaN
#
#    s57  s59
# 0  NaN  NaN
# 1  NaN  NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113387 entries, 0 to 113386
# Data columns (total 36 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      113387 non-null  object
#  1   gender  113387 non-null  object
#  2   s11     113387 non-null  object
#  3   s12     113387 non-null  object
#  4   s13     113387 non-null  int64
#  5   s16     113387 non-null  object
#  6   s17     113387 non-null  object
#  7   s18     113387 non-null  object
#  8   s48     113387 non-null  int64
#  9   s52     113387 non-null  object
#  10  s53     113387 non-null  object
#  11  s54     10371 non-null   object
#  12  s55     12627 non-null   object
#  13  s58     113387 non-null  object
#  14  s69     113387 non-null  object
#  15  s70     113387 non-null  object
#  16  s71     113387 non-null  object
#  17  n1      113387 non-null  float64
#  18  n2      113387 non-null  float64
#  19  n3      113387 non-null  int64
# ...

# %%
df.reindex()
# Out:
#                                                        id gender s11 s12  s13  \
# 0       b'gAAAAABinOicS09vrmgh0_JyEHihI13ptO0rCyHP7l76...      M   Y   N    1
# 1       b'gAAAAABinOiWGC1WhR6WYP0DA5ssGv9rIekrWUwCdJ8F...      M   Y   Y    1
# 2       b'gAAAAABinOibTcOBFIVeA4nVF3FuFz_QX3ZlPPFc21gS...      M   Y   Y    1
# 3       b'gAAAAABinOig-g3-Q1ggjlMhfUSdn21Aj5yVVeVvXbis...      F   Y   Y    1
# 4       b'gAAAAABinOiXdoaNUzihOSbyY1tjWtd5EgMaXkkvH6SV...      M   N   Y    1
# ...                                                   ...    ...  ..  ..  ...
# 113382  b'gAAAAABinOjbnJVk2-nOVQsYB9p4DK26fTLLik_UR2H0...      M   Y   Y    1
# 113383  b'gAAAAABinOi7ixyXrlKYlx8D9i0-TIPD5elP2k-vuekn...      M   Y   Y    1
# 113384  b'gAAAAABinOi31zWSlD0OMhbBd3_weh7Kq6aPeO4yYqns...      M   N   Y    1
# 113385  b'gAAAAABinOjIe7jFVk9k7jiH8Y3rdpUHDTZG2T2isunp...      M   N   Y    1
# 113386  b'gAAAAABinOiiLo4KNZVgClHgtOFRzEU9O97My6MowJFa...      M   Y   Y    1
#
# ...

# %%
corr=df.corr()
plt.figure(figsize=(15,15))
sns.heatmap(corr, annot=True, cmap='coolwarm')

# %%
from sklearn.preprocessing import LabelEncoder
cols=['gender','s11','s12','s16','s17','s18','s52','s53','s54','s55','s58','s69','s70','s71','s56','s57','s59']
le=LabelEncoder()
for col in cols:
    df[col]=le.fit_transform(df[col])
    df.head()

# %%
train1=df.iloc[:train_len,:]
test1=df.iloc[train_len:,:]

# %%
train1.tail()
# Out:
#                                                       id  gender  s11  s12  \
# 28317  b'gAAAAABinOiX2ss5U2ZT5zFd8zf7HcBDWPvbivNz5wAy...       1    1    1
# 28318  b'gAAAAABinOiabmEADrCTZQktCKiahJkR_0kDa_8WOlos...       1    1    1
# 28319  b'gAAAAABinOicscC37w1W9uiIlYL1U5D_mUtmgdUg8QTl...       0    1    1
# 28320  b'gAAAAABinOib-JZ8iQDxjSRsa1dPT1TqeSQ_si4mAw5f...       1    1    1
# 28321  b'gAAAAABinOiZ3mCQAtoJFXj-Ymjhi9FbbZ_Ypi5gDoAE...       1    1    1
#
#        s13  s16  s17  s18  s48  s52  ...        n10       n11  n12  n13  \
# 28317    1    3    3    1    0    1  ...  11.404942  1.862441    0    0
# 28318    1    3    3    1    0    1  ...   5.530054  1.671527    0    0
# 28319    1    3    3    1    0    1  ...   6.058681  1.627479    0    1
# 28320    1    1    2    1    1    1  ...  11.387646  1.560391    0    0
# 28321    1    3    3    1    1    2  ...   4.584967  1.777995    0    1
#
#             n14  n15  label  s56  s57  s59
# ...

# %%
test1.tail()
# Out:
#                                                        id  gender  s11  s12  \
# 113382  b'gAAAAABinOjbnJVk2-nOVQsYB9p4DK26fTLLik_UR2H0...       1    1    1
# 113383  b'gAAAAABinOi7ixyXrlKYlx8D9i0-TIPD5elP2k-vuekn...       1    1    1
# 113384  b'gAAAAABinOi31zWSlD0OMhbBd3_weh7Kq6aPeO4yYqns...       1    0    1
# 113385  b'gAAAAABinOjIe7jFVk9k7jiH8Y3rdpUHDTZG2T2isunp...       1    0    1
# 113386  b'gAAAAABinOiiLo4KNZVgClHgtOFRzEU9O97My6MowJFa...       1    1    1
#
#         s13  s16  s17  s18  s48  s52  ...       n10       n11  n12  n13  \
# 113382    1    2    2    2    1    2  ...  5.604845  1.746737    0    0
# 113383    1    1    2    2    1    2  ...  5.458373  1.669676    0    0
# 113384    1    3    0    2    1    1  ...  3.429928  1.500925    0    0
# 113385    1    1    3    3    1    2  ...  6.212552  1.730987    0    0
# 113386    1    3    3    1    0    1  ...  4.890686  1.844714    0    0
#
#              n14  n15  label  s56  s57  s59
# ...

# %%
X=train1.drop(columns=['id','label'],axis=1)
y=train1['label']

# %%
X.shape
# Out:
# (28322, 34)

# %%
from sklearn.model_selection import train_test_split, cross_val_score
def classify(model,x,y):
    x_train, x_test, y_train, y_test =train_test_split(X,y,test_size=0.25,random_state=42)
    model.fit(x_train, y_train)
    print('Accuracy:', model.score(x_test,y_test))
    score=cross_val_score(model,X,y,cv=5)
    print(score)
    print('CV Score:',np.mean(score))

# %%
from lightgbm import LGBMClassifier
model=LGBMClassifier()
classify(model,X,y)
# Out:
# Accuracy: 0.8839147013133738
# [0.870609   0.88526037 0.87941384 0.88365113 0.87199859]
# CV Score: 0.878186586533427

# %%
from sklearn.neural_network import MLPClassifier
model= MLPClassifier()
classify(model,X,y)
# Out:
# Accuracy: 0.8815139104646237
# [0.86972639 0.88331862 0.87517655 0.88047316 0.87146893]
# CV Score: 0.8760327314613969

# %%
from sklearn.ensemble import GradientBoostingClassifier
model= GradientBoostingClassifier()
classify(model,X,y)
# Out:
# Accuracy: 0.8853269312244033
# [0.8744925  0.88331862 0.88012006 0.88435734 0.87535311]
# CV Score: 0.8795283258784987

# %%
model=LGBMClassifier()
model.fit(X,y)
# Out:
# LGBMClassifier()

# %%
X_test=test1.drop(columns=['id','label'], axis=1)
X_test.head()
# Out:
#        gender  s11  s12  s13  s16  s17  s18  s48  s52  s53  ...         n9  \
# 28322       1    1    1    1    1    3    3    0    2    1  ...   6.646617
# 28323       1    1    1    1    1    2    1    1    2    1  ...  11.046294
# 28324       1    1    0    1    1    3    1    1    2    1  ...   2.805834
# 28325       1    1    1    1    3    3    1    0    1    1  ...   6.354938
# 28326       1    1    1    1    3    2    1    1    1    1  ...   6.810158
#
#              n10       n11  n12  n13       n14  n15  s56  s57  s59
# 28322   4.801224  1.693087    0    0  0.439270    2    0    0    0
# 28323   6.407230  1.516728    0    0  0.084334    4    0    0    0
# 28324   5.481219  1.788823    0    0  0.984210    0    0    0    0
# 28325   5.427266  1.792147    0    0  0.003492    1    0    0    0
# 28326  11.487845  1.880992    0    0  0.060614    0    0    0    0
#
# [5 rows x 34 columns]
